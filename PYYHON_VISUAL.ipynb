# %% [markdown]
# <a href="https://colab.research.google.com/github/LFRANCO3030/PYTHON_VISUAL/blob/main/PYYHON_VISUAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Visualizacion de Datos con Python Matplotlib, Seaborn y Ploty

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/PYTHON VISUAL/inmigrantes_canada.csv')
df.head(30)
# Out:
#                     Pais                  Continente  \
# 0             Afganistán                        Asia
# 1                Albania                      Europa
# 2                Argelia                      África
# 3        Samoa Americana                     Oceanía
# 4                Andorra                      Europa
# 5                 Angola                      África
# 6      Antigua y Barbuda  América Latina y el Caribe
# 7              Argentina  América Latina y el Caribe
# 8                Armenia                        Asia
# 9              Australia                     Oceanía
# 10               Austria                      Europa
# 11            Azerbaiyán                        Asia
# 12               Bahamas  América Latina y el Caribe
# 13                Baréin                        Asia
# 14             Bangladés                        Asia
# 15              Barbados  América Latina y el Caribe
# 16           Bielorrusia                      Europa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pais        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Region      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df.set_index('Pais', inplace=True)
df
# Out:
#                   Continente            Region  1980  1981  1982  1983  1984  \
# Pais
# Afganistán              Asia       Sur de Asia    16    39    39    47    71
# Albania               Europa     Sur de Europa     1     0     0     0     0
# Argelia               África   Norte de África    80    67    71    69    63
# Samoa Americana      Oceanía         Polinesia     0     1     0     0     0
# Andorra               Europa     Sur de Europa     0     0     0     0     0
# ...                      ...               ...   ...   ...   ...   ...   ...
# Vietnam                 Asia  Sudeste Asiático  1191  1829  2162  3404  7583
# Sahara Occidental     África   Norte de África     0     0     0     0     0
# Yemen                   Asia   Asia Occidental     1     2     1     6     0
# Zambia                África   África Oriental    11    17    11     7    16
# Zimbabue              África   África Oriental    72   114   102    44    32
#
# ...

# %%
anos = list(map(str, range(1980, 2014)))
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
colombia = df.loc['Colombia',anos]
colombia
# Out:
# 1980     266
# 1981     326
# 1982     360
# 1983     244
# 1984     235
# 1985     214
# 1986     257
# 1987     376
# 1988     352
# 1989     439
# 1990     614
# 1991     652
# 1992     582
# 1993     464
# 1994     375
# 1995     371
# 1996     381
# 1997     578
# 1998     929
# 1999    1306
# 2000    2259
# 2001    2965
# 2002    3283
# 2003    4318
# 2004    4566
# 2005    6424
# 2006    6535
# 2007    5357
# 2008    5452
# 2009    4652
# 2010    5218
# 2011    4366
# 2012    3741
# 2013    3631
# Name: Colombia, dtype: object

# %% [markdown]
# ###Modificacion de tamaño de letras

# %%
col_dict = {'Año':colombia.index.tolist(),
            'Inmigrantes':colombia.values.tolist()}
col_dict
# Out:
# {'Año': ['1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013'],
#  'Inmigrantes': [np.int64(266),
#   np.int64(326),
#   np.int64(360),
#   np.int64(244),
#   np.int64(235),
#   np.int64(214),
#   np.int64(257),
#   np.int64(376),
#   np.int64(352),
#   np.int64(439),
#   np.int64(614),
#   np.int64(652),
#   np.int64(582),
#   np.int64(464),
#   np.int64(375),
#   np.int64(371),
#   np.int64(381),
#   np.int64(578),
#   np.int64(929),
#   np.int64(1306),
#   np.int64(2259),
#   np.int64(2965),
#   np.int64(3283),
#   np.int64(4318),
#   np.int64(4566),
#   np.int64(6424),
#   np.int64(6535),
#   np.int64(5357),
#   np.int64(5452),
# ...

# %%
datos_col = pd.DataFrame(col_dict)
datos_col.tail()
# Out:
#      Año  Inmigrantes
# 29  2009         4652
# 30  2010         5218
# 31  2011         4366
# 32  2012         3741
# 33  2013         3631

# %% [markdown]
# ###MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.plot(datos_col['Año'], datos_col['Inmigrantes'])
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2013'])
plt.title('Migracion de colombianos a Canada')
plt.xlabel('Años')
plt.ylabel('Numero de Inmigrantes')
plt.show()

# %% [markdown]
# ###Grafico Comparativo de Inmigrantes de Argentina y Brasil

# %%
argentina = df.loc['Argentina', anos]
brasil = df.loc['Brasil', anos]

# %%
col_dict_arg = {'Año':argentina.index.tolist(),
            'Inmigrantes':argentina.values.tolist()}

col_dict_bra = {'Año':brasil.index.tolist(),
            'Inmigrantes':brasil.values.tolist()}

# %%
datos_arg = pd.DataFrame(col_dict_arg)
datos_arg.tail()
# Out:
#      Año  Inmigrantes
# 29  2009          467
# 30  2010          459
# 31  2011          278
# 32  2012          263
# 33  2013          282

# %%
datos_bra = pd.DataFrame(col_dict_bra)
datos_bra.tail()
# Out:
#      Año  Inmigrantes
# 29  2009         2509
# 30  2010         2598
# 31  2011         1508
# 32  2012         1642
# 33  2013         1714

# %%
x1 = datos_arg['Año']
y1 = datos_arg['Inmigrantes']
x2 = datos_bra['Año']
y2 = datos_bra['Inmigrantes']

# %%
#plt.figure(figsize=(10,5))
fig, ax = plt.subplots()
ax.plot(x1, y1, label='Argentina')
ax.plot(x2, y2, label='Brasil')
ax.plot(x1, y1, 'o')
ax.plot(x2, y2, 'o')
ax.legend()
plt.xticks(['1980','1985','1990','1995','2000','2005','2010','2013'])
plt.title('Migracion de Argentina y Brasil a Canada')
plt.xlabel('Años')
plt.ylabel('Numero de Inmigrantes')
plt.show()

# %% [markdown]
# ### Otra solucion de grafico comparativo

# %%
df_comparacion = df.loc[['Brasil', 'Argentina'], anos]

# %%
df_comparacion = df_comparacion.T

# %%
df_comparacion.head()
# Out:
# Pais  Brasil  Argentina
# 1980     211        368
# 1981     220        426
# 1982     192        626
# 1983     139        241
# 1984     145        237

# %%
plt.plot(df_comparacion['Brasil'], label='Brasil')
plt.plot(df_comparacion['Argentina'], label='Argentina')
plt.title('Inmigración de Brasil y Argentina a Canadá')
plt.xlabel('Año')
plt.ylabel('Número de Inmigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %% [markdown]
# ###Nuevas variantes para el grafico

# %%
fig,ax = plt.subplots(figsize=(8,4))
ax.plot(datos_col['Año'], datos_col['Inmigrantes'])
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Migracion de colombianos hacia Canada\n1980 - 2013')
#ax.set_xlabel('Años')
#ax.set_ylabel('Numero de Inmigrantes')
plt.show()

# %% [markdown]
# ###Grafico de Cajas

# %%
#(1,2) significa una fila con dos espacios para graficas
fig, axs=plt.subplots (1,2, figsize=(10,4))

axs[0].plot(datos_col['Año'], datos_col['Inmigrantes'])
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].set_title('Migracion de colombianos hacia Canada\n1980 - 2013')
axs[0].set_xlabel('Años')
axs[0].set_ylabel('Numero de Inmigrantes')
axs[0].grid()

axs[1].boxplot(datos_col['Inmigrantes'])
axs[1].set_title('Boxplot de la inmigracion de colombianos \n hacia Canada 1980 - 2013')
axs[1].set_xlabel('Colombia')
axs[1].set_ylabel('Numero de Inmigrantes')
axs[1].grid()

plt.show()

# %%
datos_col.describe()
# Out:
#        Inmigrantes
# count    34.000000
# mean   2120.235294
# std    2163.761316
# min     214.000000
# 25%     372.000000
# 50%     633.000000
# 75%    4173.750000
# max    6535.000000

# %%
fig, axs=plt.subplots (2,2, figsize=(10,6))
fig.subplots_adjust(hspace=0.5,wspace=0.3)
fig.suptitle('Inmigracion de los 4 mayores paises sudamericanos \n hacia Canada 1980 - 2013')

axs[0,0].plot(df.loc['Colombia', anos])
axs[0,0].set_title('Colombia')

axs[0,1].plot(df.loc['Brasil', anos])
axs[0,1].set_title('Brasil')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Perú', anos])
axs[1,1].set_title('Peru')

ymin = 0
ymax = 7000

for ax in axs.ravel():
  ax.set(ylim=(ymin,ymax))

for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  ax.set(xlabel='Años', ylabel='Numero de Inmigrantes')
  ax.grid()


plt.show()

# %% [markdown]
# ###Modificacion al tamaño de Letras

# %%
fig,ax = plt.subplots(figsize=(8,3))
#plt.style.use('fivethirtyeight')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Migracion de colombianos hacia Canada\n1980 - 2013', fontsize=18, loc='left')
ax.set_xlabel('Años',fontsize=14)
ax.set_ylabel('Numero de Inmigrantes',fontsize=14)
ax.plot(datos_col['Año'], datos_col['Inmigrantes'],lw=2,color='g')#marker='o'
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
plt.grid(linestyle='--')
plt.show()

# %%
sudamerica = df.query('Region == "América del Sur"')
sudamerica.head(10)
# Out:
#                            Continente           Region  1980  1981  1982  \
# Pais
# Argentina  América Latina y el Caribe  América del Sur   368   426   626
# Bolivia    América Latina y el Caribe  América del Sur    44    52    42
# Brasil     América Latina y el Caribe  América del Sur   211   220   192
# Chile      América Latina y el Caribe  América del Sur  1233  1069  1078
# Colombia   América Latina y el Caribe  América del Sur   266   326   360
# Ecuador    América Latina y el Caribe  América del Sur   238   207   184
# Guyana     América Latina y el Caribe  América del Sur  2334  2943  3575
# Paraguay   América Latina y el Caribe  América del Sur    45    26    32
# Perú       América Latina y el Caribe  América del Sur   317   456   401
# Surinam    América Latina y el Caribe  América del Sur    15    10    21
#
#            1983  1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  \
# Pais                                     ...
# ...

# %%
#Barras Verticales
colores = {'royalblue','orange','forestgreen','orchid','purple','brown','slateblue','gray','olive','navy','teal','tomato'}
fig,ax = plt.subplots(figsize=(12,5))
ax.bar(sudamerica.index, sudamerica['Total'], color=colores,width=0.9)
ax.set_title('Inmigracion de Sudamericanos a Canada \n entre le periodo 1980 - 2013',fontsize=18, loc='left')
ax.set_xlabel(' ')
ax.set_ylabel('Numero de Inmigrantes',fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=10)
plt.show()

# %%
#Barras Horizontales
colores = {'royalblue','orange','forestgreen','orchid','purple','brown','slateblue','gray','olive','navy','teal','tomato'}
fig,ax = plt.subplots(figsize=(12,5))
ax.barh(sudamerica.index, sudamerica['Total'], color=colores)
ax.set_title('Inmigracion de Sudamericanos a Canada \n entre le periodo 1980 - 2013',fontsize=18, loc='left')
ax.set_ylabel(' ')
ax.set_xlabel('Numero de Inmigrantes',fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=10)
plt.show()

# %%
sudamerica_sort = sudamerica.sort_values(by='Total', ascending=True)
sudamerica_sort

#Barras Horizontales
colores = {'royalblue','orange','forestgreen','orchid','purple','brown','slateblue','gray','olive','navy','teal','tomato'}
fig,ax = plt.subplots(figsize=(12,5))
ax.barh(sudamerica_sort.index, sudamerica_sort['Total'], color=colores)
ax.set_title('Inmigracion de Sudamericanos a Canada \n entre le periodo 1980 - 2013',fontsize=18, loc='left')
ax.set_ylabel(' ')
ax.set_xlabel('Numero de Inmigrantes',fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=10)
plt.show()

# %%
colores=[]
for Pais in sudamerica_sort.index:
  if Pais == 'Colombia':
    colores.append('forestgreen')
  else:
    colores.append('silver')

#Barras Horizontales
#colores = {'royalblue','orange','forestgreen','orchid','purple','brown','slateblue','gray','olive','navy','teal','tomato'}
fig,ax = plt.subplots(figsize=(14,7))
ax.barh(sudamerica_sort.index, sudamerica_sort['Total'], color=colores)
ax.set_title('Inmigracion de Colombianos a Canada \n entre le periodo 1980 - 2013',fontsize=18, loc='left')
ax.set_ylabel(' ')
ax.set_xlabel('Numero de Inmigrantes',fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=10)

for i,j in enumerate(sudamerica_sort['Total']):
  ax.text(j+20, i, str(j), fontsize=9 ,ha='left', va='center', fontweight='bold')

plt.show()

# %%
colores=[]
for Pais in sudamerica_sort.index:
  if Pais == 'Colombia':
    colores.append('forestgreen')
  else:
    colores.append('silver')

#Barras Horizontales
#colores = {'royalblue','orange','forestgreen','orchid','purple','brown','slateblue','gray','olive','navy','teal','tomato'}
fig,ax = plt.subplots(figsize=(14,7))

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='y', which='both', size=0)
#ax.get_yaxis().set_visible(False)

ax.barh(sudamerica_sort.index, sudamerica_sort['Total'], color=colores)
ax.set_title('Inmigracion de Colombianos a Canada \n entre le periodo 1980 - 2013',fontsize=18, loc='left')
#ax.set_ylabel(' ')
#ax.set_xlabel('Numero de Inmigrantes',fontsize=14)
ax.yaxis.set_tick_params(labelsize=10)
#ax.xaxis.set_tick_params(labelsize=10)

for i,j in enumerate(sudamerica_sort['Total']):
  ax.text(j+20, i, str(j), fontsize=9 ,ha='left', va='center', fontweight='bold')

fig.savefig('/content/drive/MyDrive/PYTHON VISUAL/Inmigrantes_sudamericanos_canada.png',transparent=False, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ###Exportar Graficos

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
fig,ax = plt.subplots(figsize=(8,3))
#plt.style.use('fivethirtyeight')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Migracion de colombianos hacia Canada\n1980 - 2013', fontsize=18, loc='left')
ax.set_xlabel('Años',fontsize=14)
ax.set_ylabel('Numero de Inmigrantes',fontsize=14)
ax.plot(datos_col['Año'], datos_col['Inmigrantes'],lw=2,color='g')#marker='o'
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
#plt.grid(linestyle='--')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#ax.spines['left'].set_visible(False)
#ax.spines['bottom'].set_visible(False)
fig.savefig('/content/drive/MyDrive/PYTHON VISUAL/migracion_colombia_canada.png',transparent=False, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ###SEABORN

# %%
import seaborn as sns

# %%
sns.set_theme()
top_10 =df.sort_values('Total', ascending=False).head(10)
top_10
# Out:
#                        Continente             Region   1980   1981   1982  \
# Pais
# India                        Asia        Sur de Asia   8880   8670   8147
# China                        Asia      Asia Oriental   5123   6682   3308
# Reino Unido                Europa    Norte de Europa  22045  24796  20620
# Filipinas                    Asia   Sudeste Asiático   6051   5921   5249
# Pakistán                     Asia        Sur de Asia    978    972   1201
# Estados Unidos  América del Norte  América del Norte   9378  10030   9074
# Irán                         Asia        Sur de Asia   1172   1429   1822
# Sri Lanka                    Asia        Sur de Asia    185    371    290
# Corea del Sur                Asia      Asia Oriental   1011   1456   1572
# Polonia                    Europa    Europa Oriental    863   2930   5881
#
#                  1983   1984  1985  1986   1987  ...   2005   2006   2007  \
# Pais                                             ...
# ...

# %%
sns.barplot(data=top_10, x='Total', y=top_10.index, orient='h')
plt.show()

# %%
ax = sns.barplot(data=top_10, x='Total', y=top_10.index, orient='h')
ax.set(title='Top 10 paises con mayor migracion a Canada\n 1980 - 2013',
    xlabel='numero de inmigrantes',
    ylabel='Paises')
plt.show()

# %%
fig, ax=plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, x='Total', y=top_10.index, orient='h')
ax.set_title('Top 10 paises con mayor migracion a Canada\n 1980 - 2013', loc='left',fontsize=16)
ax.set_xlabel('numero de temperaturas',fontsize=14)
ax.set_ylabel('')
plt.show()

# %%
def generar_grafico(palette):
  fig, ax=plt.subplots(figsize=(14,7))
  #ax.set_frame_on(False)
  #ax.get_xaxis().set_visible(False)
  #ax.tick_params(axis='y', which='both', size=0)
  ax.set(xticklabels=[])
  ax = sns.barplot(data=top_10, x='Total',y=top_10.index, hue=top_10.index, orient='h',palette=palette,legend=False)
  ax.set_title('Top 10 paises con mayor migracion a Canada\n 1980 - 2013', loc='left',fontsize=16)
  ax.set_xlabel('Numero Inmigrantes',fontsize=14)
  ax.set_ylabel('')
  sns.despine()
  for i,j in enumerate(top_10['Total']):
     ax.text(j+20, i, str(j), fontsize=9 ,ha='left', va='center', fontweight='bold')
  plt.show()

# %%
#generar_grafico('Blues_r')
#generar_grafico('rocket')
sns.set_theme(style ='darkgrid')
generar_grafico('tab10')

# %% [markdown]
# ###Graficos Interactivos

# %%
import plotly.express as px

# %%
fig = px.line(datos_col, x='Año', y='Inmigrantes',title='Inmigracion de colombianos a Canada entre 1980 y 2013')
fig.update_traces(line_color='green',line_width=2)
fig.update_layout(width=800,height=400,xaxis={'tickangle':-45},xaxis_title ='Año',yaxis_title='Numero de Inmigrantes',
                  font_family='Arial',font_size=14,font_color='black')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sudamerica.drop(['Continente','Region','Total'], axis=1, inplace=True)
sudamerica
# Out:
# <ipython-input-206-fd4e21f5f09d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Pais                                                                   ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
# Bolivia      44    52    42    49    38    44    79   165    63    68  ...
# Brasil      211   220   192   139   145   130   205   244   394   650  ...
# Chile      1233  1069  1078   781   681   533   633  1454   990  1023  ...
# Colombia    266   326   360   244   235   214   257   376   352   439  ...
# Ecuador     238   207   184   155   179   208   240   344   265   278  ...
# Guyana     2334  2943  3575  2650  1932  2299  3942  6174  2977  3270  ...
# ...

# %%
sudamerica = sudamerica.T
sudamerica
# Out:
# Pais  Argentina  Bolivia  Brasil  Chile  Colombia  Ecuador  Guyana  Paraguay  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
# 1985        196       44     130    533       214      208    2299        36
# 1986        213       79     205    633       257      240    3942        34
# 1987        519      165     244   1454       376      344    6174        72
# 1988        374       63     394    990       352      265    2977        53
# 1989        538       68     650   1023       439      278    3270        48
# 1990        678       71     650   1286       614      552    2824        56
# ...

# %%
fig = px.line(sudamerica, x=sudamerica.index, y=sudamerica.columns,title='Inmigrantes sudamericanos a Canada entre 1980 y 2013', color='Pais', markers=True)
fig.update_layout(width=1000,height=500,xaxis={'tickangle':-45},xaxis_title ='Año',yaxis_title='Numero de Inmigrantes',
                  font_family='Arial',font_size=14,font_color='black')
fig.write_html('/content/drive/MyDrive/PYTHON VISUAL/Inmigrantes_sudamericanos_canada.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objs as go

# Creando una figura
fig = go.Figure()

# Agregando la línea con los datos de Brasil
fig.add_trace(
    go.Scatter(x=[datos_bra['Año'].iloc[0]], y=[datos_bra['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes de Brasil', line=dict(width=4))
)

# Agregando la línea con los datos de Argentina
fig.add_trace(
    go.Scatter(x=[datos_arg['Año'].iloc[0]], y=[datos_arg['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes de Argentina', line=dict(width=4))
)

# Definiendo las configuraciones de diseño
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Brasil y Argentina a Canadá en el período de 1980 a 2013</b>',
        x=0.1,
        font=dict(size=18)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de inmigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1200, # Ancho de la figura en píxeles
    height=600 # Altura de la figura en píxeles
)

# Definiendo las configuraciones de animación
frames = []
for i in range(len(datos_bra)):
    frame_data = [
        go.Scatter(x=datos_bra['Año'].iloc[:i+1], y=datos_bra['Inmigrantes'].iloc[:i+1]),
        go.Scatter(x=datos_arg['Año'].iloc[:i+1], y=datos_arg['Inmigrantes'].iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando la figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
